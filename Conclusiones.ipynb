# %%
import numpy as np
import pandas as pd

# %%
df_nombres = pd.read_csv('CO_ids_nombres.csv', sep=';') 
 
mnpio1 = df_nombres.loc[df_nombres['id_mpio'] == 726]
mnpio2 = df_nombres.loc[df_nombres['id_mpio'] == 882]
mnpio3 = df_nombres.loc[df_nombres['id_mpio'] == 381]
mnpio4 = df_nombres.loc[df_nombres['id_mpio'] == 261]

#municipio con max trafico
print(mnpio1)
print(mnpio2)
print(mnpio3)
print(mnpio4)


df_secuestros  = pd.read_csv('secuestro.csv', sep=',')
df_agua = pd.read_csv('./data/agua.csv', sep=',')
df_agua['departamento'] = df_agua['departamento'].str.upper()
df_agua['municipio'] = df_agua['municipio'].str.upper()

#merged_df.sort_values(by=['],ascending=False)



df_secuestros.columns.values
df_secuestros = df_secuestros.drop(df_secuestros.columns[0], axis=1)
df_secuestros = df_secuestros.drop(df_secuestros.columns[2], axis=1)
df_secuestros = df_secuestros.drop(df_secuestros.columns[5], axis=1)
df_secuestros = df_secuestros.drop(df_secuestros.columns[5], axis=1)
df_secuestros = df_secuestros.drop(df_secuestros.columns[5], axis=1)
df_secuestros = df_secuestros.drop(df_secuestros.columns[5], axis=1)
df_secuestros = df_secuestros.drop(df_secuestros.columns[5], axis=1)
df_secuestros = df_secuestros.drop(df_secuestros.columns[6], axis=1)

df_secuestros = df_secuestros[7:]
df_secuestros.columns = df_secuestros.iloc[0]
df_secuestros = df_secuestros[1:]
df_secuestros 

df_secuestros=df_secuestros.dropna(axis=0,how='any')
 
df_secuestros =df_secuestros.sort_values(by=df_secuestros.columns[5],ascending=False)

#municipios con mas secuestros en 2015
secuestros1 = ('MEDELLÍN',2)
secuestros1 = ('SARDINATA',2)
secuestros1 = ('BOGOTÁ ',1)
secuestros1 = ('SAN CAYETANO',1)
df_secuestros



df_necesidades =df_secuestros  = pd.read_csv('151106People_In_Need_Dpto.csv', sep=';') 
df_necesidades
# Out:
#      id_mpio             nombre_mpio  id_dpto            nombre_dpto
# 909      726  SANTAFE DE BOGOTA D.C.       11  SANTAFE DE BOGOTA D.C
#       id_mpio nombre_mpio  id_dpto      nombre_dpto
# 1079      882        CALI       76  VALLE DEL CAUCA
#     id_mpio nombre_mpio  id_dpto nombre_dpto
# 79      381    MEDELLIN        5   ANTIOQUIA
#      id_mpio  nombre_mpio  id_dpto nombre_dpto
# 918      261  BUCARAMANGA       68   SANTANDER
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-99-2eb63c9ec3e1> in <module>()
#      50
#      51
# ---> 52 df_necesidades =df_secuestros  = pd.read_csv('151106People_In_Need_Dpto.csv', sep=';')
#      53 df_necesidades
#
# ...

# %%
df_violencia  = pd.read_csv('./data/Violencia.csv', sep=',')
df_violencia = df_violencia.sort_values(by='CASOS 2015',ascending=False)

#municipios con mas viloencia
violencia1 = ('Pasto',1072)
violencia2 = ('Tumaco',585)
violencia3 = ('Ipiales',299)
violencia4 = ('Tuquerres',60)

df_violencia
# Out:
#                 Codigo     # Región          Municipios  POBLACIÓN 2008  \
# 19  TOTAL DEPARTAMENTO   NaN    NaN                 NaN         1599646
# 0                52001   1.0    CEN               Pasto          400055
# 5                52835  62.0    PAS              Tumaco          171281
# 25               52356  30.0    EXP             Ipiales          117482
# 7                52838  63.0    SAB           Túquerres           41194
# 41               52079   6.0    TEL           Barbacoas           32402
# 4                52418  38.0    GUA           Los Andes           17145
# 37               52678  52.0    ABA           Samaniego           50173
# 22               52110   8.0    JUA             Buesaco           23038
# 57               52540  45.0    COR           Policarpa           14665
# 31               52506  44.0    SAB              Ospina            8403
# 30               52490  43.0    SAN       Olaya Herrera           28589
# ...
